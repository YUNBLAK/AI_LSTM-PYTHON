# %%
import os
import math
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.preprocessing import *
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import LSTM
from tensorflow.keras.models import *
from tensorflow.keras.utils import *

def csvloader(filename):
    return pd.read_csv(filename)

def make_dataset(data, label, window_size = 120):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i : i + window_size]))
        label_list.append(np.array(label.iloc[i + window_size]))
    return np.array(feature_list), np.array(label_list)

def ModelLayer(df, predictLabel, b_size): 
    df_scaled = pd.DataFrame(df[predictLabel])
    df_scaled.columns = [predictLabel]
    TEST_SIZE = b_size * 2
    
    train = df_scaled[ : -TEST_SIZE]
    train_feature = train[[predictLabel]]
    train_label = train[predictLabel]
    train_feature, train_label = make_dataset(train_feature, train_label, b_size)
    x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size = b_size / len(df) * 2)
    
    model = Sequential()
    model.add(LSTM(16, 
                   input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                   activation='relu', 
                   return_sequences=False))
    
    # IF YOU WANT TO ADD LAYER
    model.add(Dense(1))
    model.compile(loss = 'mean_squared_error', 
                  optimizer = 'adam')
    
    
    early_stop = EarlyStopping(monitor='val_loss', 
                               patience = 5)
    
    # IF YOU WANT TO SAVE MODEL WEIGHTS
    model_path = 'model'
    filename = os.path.join(model_path, 'MODELWEIGHT.h5')
    checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    
    history = model.fit(x_train, 
                        y_train, 
                        epochs = 100, 
                        batch_size = b_size,
                        validation_data = (x_valid, y_valid), 
                        callbacks = [early_stop, checkpoint])
    
    #IF YOU WANT TO SAVE MODEL
    model.save("MODELDATA.h5")
    
    return model
    
def test_features(df, predictLabel, b_size):
    df_scaled = pd.DataFrame(df[predictLabel])
    df_scaled.columns = [predictLabel]
    TEST_SIZE = b_size * 2
    test = df_scaled[-TEST_SIZE : ]
    feature_cols = [predictLabel]
    test_feature = test[feature_cols]
    test_label = test[predictLabel]
    test_feature, test_label = make_dataset(test_feature, test_label, b_size)
    return test_feature

def newFeatureCreator_FST(df, model, predictLabel, b_size):
    model_cases = test_features(df, predictLabel, b_size)
    model_pred = model.predict(model_cases)
    arr = [abs(round(model_pred[-1][0], 4))]
    return arr

def newFeatureCreator(df, model, feature):
    model_cases = feature
    model_pred = model.predict(model_cases)
    arr = [abs(round(model_pred[-1][0], 4))]
    return arr

def rotationFeature(feature):
    temp = []
    for i in range(0, len(feature)):
        if i == 0:
            temp = feature[i]
        elif i < len(feature) - 1:
            feature[i] = feature[i + 1]
        else:
            feature[i] = temp
    return feature

def processor(num, data, original_feat, model, one, predictLabel, b_size):
    lst = []
    feat = original_feat
    lst.append(one)
    for i in range(0, num):
        arr = newFeatureCreator(data, model, feat)
        newfeature = rotationFeature(feat[-1])
        newfeature[-1] = arr
        feat = test_features(data, predictLabel, b_size)
        feat[-1] = newfeature
        lst.append(arr)
        # print(arr)
    return lst

def LSTMMODEL(df, predictLabel, batch_size, days):
    model = ModelLayer(df, predictLabel, batch_size)
    arr = newFeatureCreator_FST(df, model, predictLabel, batch_size)
    feature = rotationFeature(test_features(df, predictLabel, batch_size)[-1])
    feature[-1] = arr
    newfeature = test_features(df, predictLabel, batch_size)
    newfeature[-1] = feature
    lst = processor(days, df, newfeature, model, arr, predictLabel, batch_size)
    return lst

def main():
    df = csvloader("NEWCH.csv")
    
    # NEXT FUTURE n DATA PREDICTION
    # IF DAYS is 7, IT MEANS THAT 7 OUTPUT WILL COME OUT
    days = 7
    label = "middle"
    batch_size = 120
    arr = LSTMMODEL(df, label, batch_size, days)
    print("NEXT 7 DATA ARE:", arr)
    
    
if __name__ == "__main__":
    main()
# Out:
# Epoch 1/100
# 28/28 [==============================] - 2s 49ms/step - loss: 0.0018 - val_loss: 9.1130e-04
#
# Epoch 00001: val_loss improved from inf to 0.00091, saving model to model/MODELWEIGHT.h5
# Epoch 2/100
# 28/28 [==============================] - 1s 42ms/step - loss: 8.2541e-04 - val_loss: 5.8778e-04
#
# Epoch 00002: val_loss improved from 0.00091 to 0.00059, saving model to model/MODELWEIGHT.h5
# Epoch 3/100
# 28/28 [==============================] - 1s 42ms/step - loss: 5.5670e-04 - val_loss: 4.9810e-04
#
# Epoch 00003: val_loss improved from 0.00059 to 0.00050, saving model to model/MODELWEIGHT.h5
# Epoch 4/100
# 28/28 [==============================] - 1s 42ms/step - loss: 4.9800e-04 - val_loss: 4.9288e-04
#
# Epoch 00004: val_loss improved from 0.00050 to 0.00049, saving model to model/MODELWEIGHT.h5
# Epoch 5/100
# 28/28 [==============================] - 1s 43ms/step - loss: 4.8515e-04 - val_loss: 4.7606e-04
#
# Epoch 00005: val_loss improved from 0.00049 to 0.00048, saving model to model/MODELWEIGHT.h5
# Epoch 6/100
# 28/28 [==============================] - 1s 42ms/step - loss: 4.6854e-04 - val_loss: 4.6419e-04
#
# Epoch 00006: val_loss improved from 0.00048 to 0.00046, saving model to model/MODELWEIGHT.h5
# Epoch 7/100
# 28/28 [==============================] - 1s 43ms/step - loss: 4.5455e-04 - val_loss: 4.5151e-04
#
# Epoch 00007: val_loss improved from 0.00046 to 0.00045, saving model to model/MODELWEIGHT.h5
# Epoch 8/100
# 28/28 [==============================] - 1s 43ms/step - loss: 4.3688e-04 - val_loss: 4.3020e-04
#
# Epoch 00008: val_loss improved from 0.00045 to 0.00043, saving model to model/MODELWEIGHT.h5
# Epoch 9/100
# 28/28 [==============================] - 1s 43ms/step - loss: 4.2099e-04 - val_loss: 4.1229e-04
#
# Epoch 00009: val_loss improved from 0.00043 to 0.00041, saving model to model/MODELWEIGHT.h5
# Epoch 10/100
# 28/28 [==============================] - 1s 43ms/step - loss: 4.0371e-04 - val_loss: 3.9312e-04
#
# Epoch 00010: val_loss improved from 0.00041 to 0.00039, saving model to model/MODELWEIGHT.h5
# Epoch 11/100
# 28/28 [==============================] - 1s 42ms/step - loss: 3.8253e-04 - val_loss: 3.7113e-04
#
# Epoch 00011: val_loss improved from 0.00039 to 0.00037, saving model to model/MODELWEIGHT.h5
# Epoch 12/100
# 28/28 [==============================] - 1s 43ms/step - loss: 3.6018e-04 - val_loss: 3.4952e-04
#
# Epoch 00012: val_loss improved from 0.00037 to 0.00035, saving model to model/MODELWEIGHT.h5
# Epoch 13/100
# 28/28 [==============================] - 1s 43ms/step - loss: 3.3751e-04 - val_loss: 3.2338e-04
#
# Epoch 00013: val_loss improved from 0.00035 to 0.00032, saving model to model/MODELWEIGHT.h5
# Epoch 14/100
# 28/28 [==============================] - 1s 43ms/step - loss: 3.1550e-04 - val_loss: 3.0960e-04
#
# Epoch 00014: val_loss improved from 0.00032 to 0.00031, saving model to model/MODELWEIGHT.h5
# Epoch 15/100
# 28/28 [==============================] - 1s 42ms/step - loss: 2.8700e-04 - val_loss: 2.6495e-04
#
# Epoch 00015: val_loss improved from 0.00031 to 0.00026, saving model to model/MODELWEIGHT.h5
# Epoch 16/100
# 28/28 [==============================] - 1s 42ms/step - loss: 2.5570e-04 - val_loss: 2.2666e-04
#
# Epoch 00016: val_loss improved from 0.00026 to 0.00023, saving model to model/MODELWEIGHT.h5
# Epoch 17/100
# 28/28 [==============================] - 1s 43ms/step - loss: 2.2868e-04 - val_loss: 1.8774e-04
#
# Epoch 00017: val_loss improved from 0.00023 to 0.00019, saving model to model/MODELWEIGHT.h5
# Epoch 18/100
# 28/28 [==============================] - 1s 43ms/step - loss: 1.9650e-04 - val_loss: 1.7033e-04
#
# Epoch 00018: val_loss improved from 0.00019 to 0.00017, saving model to model/MODELWEIGHT.h5
# Epoch 19/100
# 28/28 [==============================] - 1s 43ms/step - loss: 1.8288e-04 - val_loss: 1.5800e-04
#
# Epoch 00019: val_loss improved from 0.00017 to 0.00016, saving model to model/MODELWEIGHT.h5
# Epoch 20/100
# 28/28 [==============================] - 1s 43ms/step - loss: 1.7116e-04 - val_loss: 1.4964e-04
#
# Epoch 00020: val_loss improved from 0.00016 to 0.00015, saving model to model/MODELWEIGHT.h5
# Epoch 21/100
# 28/28 [==============================] - 1s 43ms/step - loss: 1.6725e-04 - val_loss: 1.4335e-04
#
# Epoch 00021: val_loss improved from 0.00015 to 0.00014, saving model to model/MODELWEIGHT.h5
# Epoch 22/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.5870e-04 - val_loss: 1.3823e-04
#
# Epoch 00022: val_loss improved from 0.00014 to 0.00014, saving model to model/MODELWEIGHT.h5
# Epoch 23/100
# 28/28 [==============================] - 1s 43ms/step - loss: 1.4959e-04 - val_loss: 1.2956e-04
#
# Epoch 00023: val_loss improved from 0.00014 to 0.00013, saving model to model/MODELWEIGHT.h5
# Epoch 24/100
# 28/28 [==============================] - 1s 43ms/step - loss: 1.4063e-04 - val_loss: 1.3658e-04
#
# Epoch 00024: val_loss did not improve from 0.00013
# Epoch 25/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.3393e-04 - val_loss: 1.2211e-04
#
# Epoch 00025: val_loss improved from 0.00013 to 0.00012, saving model to model/MODELWEIGHT.h5
# Epoch 26/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.2181e-04 - val_loss: 1.1278e-04
#
# Epoch 00026: val_loss improved from 0.00012 to 0.00011, saving model to model/MODELWEIGHT.h5
# Epoch 27/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.1233e-04 - val_loss: 9.8493e-05
#
# Epoch 00027: val_loss improved from 0.00011 to 0.00010, saving model to model/MODELWEIGHT.h5
# Epoch 28/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.1367e-04 - val_loss: 1.1017e-04
#
# Epoch 00028: val_loss did not improve from 0.00010
# Epoch 29/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.0247e-04 - val_loss: 1.1527e-04
#
# Epoch 00029: val_loss did not improve from 0.00010
# Epoch 30/100
# 28/28 [==============================] - 1s 43ms/step - loss: 9.3994e-05 - val_loss: 1.1170e-04
#
# Epoch 00030: val_loss did not improve from 0.00010
# Epoch 31/100
# 28/28 [==============================] - 1s 42ms/step - loss: 7.9541e-05 - val_loss: 9.9981e-05
#
# Epoch 00031: val_loss did not improve from 0.00010
# Epoch 32/100
# 28/28 [==============================] - 1s 43ms/step - loss: 6.9056e-05 - val_loss: 6.7962e-05
#
# Epoch 00032: val_loss improved from 0.00010 to 0.00007, saving model to model/MODELWEIGHT.h5
# Epoch 33/100
# 28/28 [==============================] - 1s 43ms/step - loss: 8.8690e-05 - val_loss: 9.8693e-05
#
# Epoch 00033: val_loss did not improve from 0.00007
# Epoch 34/100
# 28/28 [==============================] - 1s 42ms/step - loss: 8.8633e-05 - val_loss: 8.0546e-05
#
# Epoch 00034: val_loss did not improve from 0.00007
# Epoch 35/100
# 28/28 [==============================] - 1s 43ms/step - loss: 7.1836e-05 - val_loss: 6.3027e-05
#
# Epoch 00035: val_loss improved from 0.00007 to 0.00006, saving model to model/MODELWEIGHT.h5
# Epoch 36/100
# 28/28 [==============================] - 1s 43ms/step - loss: 5.9303e-05 - val_loss: 1.2648e-04
#
# Epoch 00036: val_loss did not improve from 0.00006
# Epoch 37/100
# 28/28 [==============================] - 1s 44ms/step - loss: 6.8465e-05 - val_loss: 6.2843e-05
#
# Epoch 00037: val_loss improved from 0.00006 to 0.00006, saving model to model/MODELWEIGHT.h5
# Epoch 38/100
# 28/28 [==============================] - 1s 42ms/step - loss: 5.7316e-05 - val_loss: 5.2159e-05
#
# Epoch 00038: val_loss improved from 0.00006 to 0.00005, saving model to model/MODELWEIGHT.h5
# Epoch 39/100
# 28/28 [==============================] - 1s 42ms/step - loss: 5.2215e-05 - val_loss: 4.3243e-05
#
# Epoch 00039: val_loss improved from 0.00005 to 0.00004, saving model to model/MODELWEIGHT.h5
# Epoch 40/100
# 28/28 [==============================] - 1s 43ms/step - loss: 4.8398e-05 - val_loss: 4.4102e-05
#
# Epoch 00040: val_loss did not improve from 0.00004
# Epoch 41/100
# 28/28 [==============================] - 1s 43ms/step - loss: 4.2520e-05 - val_loss: 3.9141e-05
#
# Epoch 00041: val_loss improved from 0.00004 to 0.00004, saving model to model/MODELWEIGHT.h5
# Epoch 42/100
# 28/28 [==============================] - 1s 43ms/step - loss: 5.5765e-05 - val_loss: 5.3979e-05
#
# Epoch 00042: val_loss did not improve from 0.00004
# Epoch 43/100
# 28/28 [==============================] - 1s 42ms/step - loss: 4.6724e-05 - val_loss: 6.0381e-05
# Epoch 00043: val_loss did not improve from 0.00004
# Epoch 44/100
# 28/28 [==============================] - 1s 42ms/step - loss: 4.5219e-05 - val_loss: 3.6979e-05
#
# Epoch 00044: val_loss improved from 0.00004 to 0.00004, saving model to model/MODELWEIGHT.h5
# Epoch 45/100
# 28/28 [==============================] - 1s 43ms/step - loss: 3.2422e-05 - val_loss: 4.9100e-05
#
# Epoch 00045: val_loss did not improve from 0.00004
# Epoch 46/100
# 28/28 [==============================] - 1s 42ms/step - loss: 4.3000e-05 - val_loss: 3.7714e-05
#
# Epoch 00046: val_loss did not improve from 0.00004
# Epoch 47/100
# 28/28 [==============================] - 1s 43ms/step - loss: 3.5027e-05 - val_loss: 3.4024e-05
#
# Epoch 00047: val_loss improved from 0.00004 to 0.00003, saving model to model/MODELWEIGHT.h5
# Epoch 48/100
# 28/28 [==============================] - 1s 43ms/step - loss: 3.2380e-05 - val_loss: 4.2225e-05
#
# Epoch 00048: val_loss did not improve from 0.00003
# Epoch 49/100
# 28/28 [==============================] - 1s 43ms/step - loss: 3.6070e-05 - val_loss: 3.6476e-05
#
# Epoch 00049: val_loss did not improve from 0.00003
# Epoch 50/100
# 28/28 [==============================] - 1s 42ms/step - loss: 3.1440e-05 - val_loss: 5.1242e-05
#
# Epoch 00050: val_loss did not improve from 0.00003
# Epoch 51/100
# 28/28 [==============================] - 1s 42ms/step - loss: 3.7377e-05 - val_loss: 4.2258e-05
#
# Epoch 00051: val_loss did not improve from 0.00003
# Epoch 52/100
# 28/28 [==============================] - 1s 42ms/step - loss: 3.3358e-05 - val_loss: 5.7826e-05
#
# Epoch 00052: val_loss did not improve from 0.00003
# NEXT 7 DATA ARE: [[0.0631], [0.0625], [0.0652], [0.0703], [0.0765], [0.0824], [0.0869], [0.0894]]
